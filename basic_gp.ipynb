# %%
import GPy

# %% [markdown]
# As of Mon 12th of Oct running on devel branch of GPy 0.8.8

# %%
GPy.plotting.change_plotting_library('plotly')

# %% [markdown]
# # Gaussian process regression tutorial
#
# ### Nicolas Durrande 2013
# #### with edits by James Hensman and Neil D. Lawrence
#
# We will see in this tutorial the basics for building a 1 dimensional and a 2 dimensional Gaussian process regression model, also known as a kriging model.
#
# We first import the libraries we will need:

# %%
import numpy as np

# %% [markdown]
# ## 1-dimensional model
#
# For this toy example, we assume we have the following inputs and outputs:

# %%
np.random.seed(0)
X = np.random.uniform(-3.,3.,(20,1))
Y = np.sin(X) + np.random.randn(20,1)*0.05

# %% [markdown]
# Note that the observations Y include some noise.
#
# The first step is to define the covariance kernel we want to use for the model. We choose here a kernel based on Gaussian kernel (i.e. rbf or square exponential):

# %%
kernel = GPy.kern.RBF(input_dim=1, variance=1., lengthscale=1.)

# %% [markdown]
# The parameter input_dim stands for the dimension of the input space. The parameters `variance` and `lengthscale` are optional, and default to 1. Many other kernels are implemented, type `GPy.kern.<tab>` to see a list

# %%
#type GPy.kern.<tab> here:
GPy.kern.BasisFuncKernel?
# Out:
# Init signature: GPy.kern.BasisFuncKernel(*args, **kw)
# Docstring:
# Parameterized class
#
# Say m is a handle to a parameterized class.
#
# Printing parameters:
#
#     - print m:           prints a nice summary over all parameters
#     - print m.name:      prints details for param with name 'name'
#     - print m[regexp]: prints details for all the parameters
#                          which match (!) regexp
#     - print m['']:       prints details for all parameters
#
#     Fields:
#
#         Name:       The name of the param, can be renamed!
#         Value:      Shape or value, if one-valued
#         Constrain:  constraint of the param, curly "{c}" brackets indicate
#                     some parameters are constrained by c. See detailed print
#                     to get exact constraints.
#         Tied_to:    which paramter it is tied to.
#
# Getting and setting parameters:
#
#     Set all values in param to one:
#
#         m.name.to.param = 1
#
# Handling of constraining, fixing and tieing parameters:
#
#     You can constrain parameters by calling the constrain on the param itself, e.g:
#
#         - m.name[:,1].constrain_positive()
#         - m.name[0].tie_to(m.name[1])
#
#     Fixing parameters will fix them to the value they are right now. If you change
#     the parameters value, the param will be fixed to the new value!
#
#     If you want to operate on all parameters use m[''] to wildcard select all paramters
#     and concatenate them. Printing m[''] will result in printing of all parameters in detail.
# Init docstring:
# Abstract superclass for kernels with explicit basis functions for use in GPy.
#
# This class does NOT automatically add an offset to the design matrix phi!
# File:           ~/opt/anaconda3/lib/python3.7/site-packages/GPy/kern/src/basis_funcs.py
# Type:           KernCallsViaSlicerMeta
# Subclasses:     PolynomialBasisFuncKernel, LinearSlopeBasisFuncKernel, ChangePointBasisFuncKernel, LogisticBasisFuncKernel

# %% [markdown]
# The inputs required for building the model are the observations and the kernel:

# %%
m = GPy.models.GPRegression(X,Y,kernel)
# Out:
# trigger parameters changed.
# ExactGaussianInference inference:

# %% [markdown]
# By default, some observation noise is added to the model. The functions `display` and `plot` give an insight of the model we have just built:

# %%
from IPython.display import display
display(m)
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 22.684176750057798<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
fig = m.plot()
GPy.plotting.show(fig, filename='basic_gp_regression_notebook')
# Out:
# PosteriorExact _raw_predict
# PosteriorExact _raw_predict
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-2940da00d723> in <module>
#       1 fig = m.plot()
# ----> 2 GPy.plotting.show(fig, filename='basic_gp_regression_notebook')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/GPy/plotting/__init__.py in show(figure, **kwargs)
#     132     for showing/drawing a figure.
#     133     """
# --> 134     return plotting_library().show_canvas(figure, **kwargs)
#     135
#     136
#
# ~/opt/anaconda3/lib/python3.7/site-packages/GPy/plotting/matplot_dep/plot_definitions.py in show_canvas(self, ax, **kwargs)
#      94
#      95     def show_canvas(self, ax, **kwargs):
# ---> 96         ax.figure.canvas.draw()
#      97         return ax.figure
#      98
#
# AttributeError: 'dict' object has no attribute 'figure'

# %% [markdown]
# The above cell shows our GP regression model before optimization of the parameters. The shaded region corresponds to ~95% confidence intervals (ie +/- 2 standard deviation).
#
# The default values of the kernel parameters may not be optimal for the current data (for example, the confidence intervals seems too wide on the previous figure). A common approach is to find the values of the parameters that maximize the likelihood of the data. It as easy as calling `m.optimize` in GPy:

# %%
m.optimize(messages=True)
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0, max=1000), HTML(value=''))), Box(children=(HTML(value=''),)…
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:

# %% [markdown]
# If we want to perform some restarts to try to improve the result of the optimization, we can use the `optimize_restarts` function. This selects random (drawn from $N(0,1)$) initializations for the parameter values, optimizes each, and sets the model to the best solution found.

# %%
m.optimize_restarts(num_restarts = 10)
# Out:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# Optimization restart 1/10, f = -16.9034566709394
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# Optimization restart 2/10, f = -16.903456670665925
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# Optimization restart 3/10, f = -16.903456670783385
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# Optimization restart 4/10, f = -16.903456670941193
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# Optimization restart 5/10, f = -16.903456670941154
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# Optimization restart 6/10, f = -16.903456670940905
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# Optimization restart 7/10, f = -16.903456670913876
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# Optimization restart 8/10, f = -16.90345667093591
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# Optimization restart 9/10, f = -16.903456670684946
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# Optimization restart 10/10, f = -16.903456670941054
# trigger parameters changed.
# ExactGaussianInference inference:
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7ffe5624b610>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7ffe5625e310>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7ffe5625e390>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7ffe5624be50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7ffe5624b710>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7ffe5624b9d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7ffe5625e7d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7ffe5625ebd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7ffe5624bcd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7ffe52b9ad50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7ffe52b9ae90>]

# %% [markdown]
# In this simple example, the objective function (usually!) has only one local minima, and each of the found solutions are the same.
#
# Once again, we can use `print(m)` and `m.plot()` to look at the resulting model resulting model. This time, the paraemters values have been optimized agains the log likelihood (aka the log marginal likelihood): the fit shoul dbe much better.

# %%
display(m)
fig = m.plot()
GPy.plotting.show(fig, filename='basic_gp_regression_notebook_optimized')
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -16.903456670941193<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>                value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right>   0.6148044471516443</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>   1.6500306872584283</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>0.0022700432842968524</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>
# PosteriorExact _raw_predict
# PosteriorExact _raw_predict
# <div>
#
#
#             <div id="eaecc9ea-aca6-40c9-ad56-27028aff77f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eaecc9ea-aca6-40c9-ad56-27028aff77f8")) {
#                     Plotly.newPlot(
#                         'eaecc9ea-aca6-40c9-ad56-27028aff77f8',
#                         [{"marker": {"color": "black", "symbol": "x"}, "mode": "markers", "name": "Data", "showlegend": true, "type": "scatter", "x": [0.2928810235639485, 1.2911361982345166, 0.616580256429863, 0.2692990979813814, -0.45807120396657197, 0.8753646783999365, -0.3744767324238447, 2.3506380046924784, 2.7819765630061752, -0.699350887045334, 1.7503502284959875, 0.17336951851742688, 0.4082673665635941, 2.553579829755966, -2.573783650812678, -2.4772242017907558, -2.878689615358046, 1.9957190732876278, 1.6689405056991031, 2.2200728894809147], "xaxis": "x", "y": [0.3634157113855967, 0.9508913950057938, 0.5939018979286954, 0.22335107529457948, -0.5698684705262387, 0.8004581386735297, -0.32256376455303165, 0.6739166227578858, 0.4654026389197021, -0.7164393663106599, 0.9862113855444424, 0.16314313598605107, 0.47365865697839754, 0.6281766384834632, -0.5300387809835279, -0.5976539078430804, -0.3042742190971406, 0.812030760050728, 
-0.6243790895521935, -0.5817107515243225, -0.5390424134964515, -0.49637407546858014, -0.4537057374407092, -0.41103739941283823, -0.3683690613849673, -0.3257007233570963, -0.2830323853292249, -0.2403640473013544, -0.197695709273483, -0.1550273712456125, -0.1123590332177411, -0.06969069518987059, -0.02702235716199919, 0.01564598086587221, 0.05831431889374272, 0.10098265692161412, 0.14365099494948463, 0.18631933297735603, 0.22898767100522655, 0.27165600903309794, 0.31432434706096934, 0.35699268508883986, 0.39966102311671126, 0.44232936114458177, 0.48499769917245317, 0.5276660372003237, 0.5703343752281951, 0.6130027132560665, 0.655671051283937, 0.6983393893118084, 0.7410077273396789, 0.7836760653675503, 0.8263444033954208, 0.8690127414232922, 0.9116810794511636, 0.9543494174790341, 0.9970177555069055, 1.039686093534776, 1.0823544315626474, 1.125022769590518, 1.1676911076183893, 1.2103594456462607, 1.2530277836741313, 1.2956961217020027, 1.3383644597298732, 1.3810327977577446, 1.423701135785615, 1.4663694738134865, 1.5090378118413579, 1.5517061498692284, 1.5943744878970998, 1.6370428259249703, 1.679711 ...

# %% [markdown]
# ## 2-dimensional example
#
# Here is a 2 dimensional example:

# %%
# sample inputs and outputs
X = np.random.uniform(-3.,3.,(50,2))
Y = np.sin(X[:,0:1]) * np.sin(X[:,1:2])+np.random.randn(50,1)*0.05

# define kernel
ker = GPy.kern.Matern52(2,ARD=True) + GPy.kern.White(2)

# create simple GP model
m = GPy.models.GPRegression(X,Y,ker)

# optimize and plot
m.optimize(messages=True,max_f_eval = 1000)
fig = m.plot()
display(GPy.plotting.show(fig, filename='basic_gp_regression_notebook_2d'))
display(m)
# Out:
# trigger parameters changed.
# ExactGaussianInference inference:
# HBox(children=(VBox(children=(IntProgress(value=0, max=1000), HTML(value=''))), Box(children=(HTML(value=''),)…
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# trigger parameters changed.
# ExactGaussianInference inference:
# PosteriorExact _raw_predict
# PosteriorExact _raw_predict
# <div>
#
#
#             <div id="2f85cc53-d459-44be-8e04-d3cc575552df" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2f85cc53-d459-44be-8e04-d3cc575552df")) {
#                     Plotly.newPlot(
#                         '2f85cc53-d459-44be-8e04-d3cc575552df',
#                         [{"marker": {"color": [-0.5459564844990004, -0.45845537975490336, -0.06815567898544461, 0.2442582561690179, -0.7158969649721664, -0.6541797938475375, 0.9489498474385616, -0.17424604972030663, -0.09957584488113175, -0.9256039551581937, 0.33252187773330066, -0.44373572365181196, 0.3060328954186731, -0.44795263349091136, -0.31393329582816504, -0.8776446595746129, -0.586906924384097, 0.40987016948119187, 0.6340407531515191, -0.04961748586027059, 0.27778752643189536, -0.2877681346459302, 0.3322787947899626, -0.7329246465237862, -0.2652041960285408, 0.7022681887534634, 0.25359132321325684, 0.29293748596971375, -0.39366216926760383, -0.4334104442733019, -0.2508216112440534, 0.9531229162872608, -0.37969599848501695, 0.18482365236113535, -0.7246317961179378, -0.6260229842642968, -0.6383239357804386, 0.3477264870456182, 0.24475824709866453, -0.2776569547249396, 0.7874661787219234, 0.22271717278490227, 0.08786596831792619, -0.9367374841084999, -0.16791442505936868, 0.2747629969770148, -1.0582444237070023, -0.48920733739898287, -0.3047538903004389, -0.6392726078991574], "colorscale": [[0.0, "rgb(0,0,0)"], [0.3333333333333333, "rgb(230,0,0)"], [0.6666666666666666, "rgb(255,210,0)"], [1.0, "rgb(255,255,255)"]], "line": {"color": "black", "width": 0.5}, "opacity": 1.0, "size": 5, "symbol": "circle-dot"}, "mode": "markers", "name": "Data", "showlegend": true, "type": "scatter", "x": [-2.615115021907294, 0.3996087252394509, 0.13948832080019802, 0.45567897333707563, -1.088586285292058, -2.2092128255736467, -1.2635634423167934, 0.5190776088604991, 1.9736401753041788, 1.0668992207773806, 1.4111641327355695, -1.5074811388802518, 0.5522515876310341, -1.6615102041562901, -0.31724772829423564, 1.1968756519050263, 1.8827869182148635, 2.2866191826669695, 2.290412171129117, 1.3515256789178434, 2.7365018083393435, -0.45686970865092214, -2.8848408101439986, 0.9610412249561104, 0.7080925739930493, -2.187155614665299, 0.41978946420758945, 0.44595149309747306, 0.9126196200101333, 2.379279575106378, -0.3848104484062391, 1.8371639342765143, -2.3986386761261933, 1.285447797294669, -2.1033101720520375, -2.025042391941751, -2.257080102903351, 1.8439137523500637, -0.556900216644002, 1.1845726388673814, 1.332333596822087, 2.853129030017315, -2.9297154948899884, 1.3799433745443483, 0.12621963722477592, -1.8000208506215996, 1.7621862201445238, -0.927889915818584, 1.226486411541197, -2.0118350610125235], "xaxis": "x", "y": [1.1548327162201186, -1.4076630543633275, -2.43635693544935, 2.5757771854572846, 1.0044622797820901, 1.2979632247113937, -1.900851827957299, -2.8793547228750387, -2.9718271428447176, -1.379952160847011, 2.7731312707046296, 0.4569440065070216, 0.43351143474524, 2.71649406910191, 2.0784520348267668, -1.215378294869198, -0.6209655549180919, 0.48763723581515217, 1.155189540466595, 0.007946291560213758, 0.8639411953778247, 0.6383592847675459, -1.190551099952704, -1.2595343567373356, -0.4273877943254032, -1.2103060442638154, 0.5452365674890394, 0.9192049191428016, -0.4114893873961565, -0.794628779712621, 2.3515401300940324, 1.223331501242198, 2.516895682468041, 2.9930820394071986, 2.2087563442092852, 0.6933573857030648, 2.088049375933407, 0.4146044316875601, -2.5849980272691715, -0.2787439039315869, 2.198293955571775, 2.134820054355666, -0.8401316131298167, -1.970221936431357, -2.6739720699644782, -2.888869233236316, -1.6564518716377192, 2.568487760793545, -2.808966422812153, 0.7288704089985814], "yaxis": "y"}, {"colorscale": [[0.0, "rgb(0,0,0)"], [0.3333333333333333, "rgb(230,0,0)"], [0.6666666666666666, "rgb(255,210,0)"], [1.0, "rgb(255,255,255)"]], "name": "Mean", "type": "contour", "x": [-3.3634288342580363, -3.1678326223861717, -2.972236410514307, -2.7766401986424425, -2.5810439867705774, -2.385447774898713, -2.1898515630268482, -1.9942553511549834, -1.7986591392831188, -1.6030629274112542, -1.4074667155393894, -1.2118705036675248, -1.0162742917956602, -0.8206780799237956, -0.6250818680519306, -0.42948565618006596, -0.23388944 ...
# None
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -19.258232256749963<br>
# <b>Number of Parameters</b>: 5<br>
# <b>Number of Optimization Parameters</b>: 5<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>                value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.Mat52.variance     </td><td class=tg-right>   0.3448325826181524</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.Mat52.lengthscale  </td><td class=tg-right>                 (2,)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.white.variance     </td><td class=tg-right>0.0008479976766703858</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>0.0008479976766703858</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %% [markdown]
# The flag `ARD=True` in the definition of the `Matern` kernel specifies that we want one lengthscale parameter per dimension (ie the GP is not isotropic). Note that for 2-d plotting, only the mean is shown.

# %% [markdown]
# ## Plotting slices
# To see the uncertaintly associated with the above predictions, we can plot slices through the surface. this is done by passing the optional `fixed_inputs` argument to the plot function. `fixed_inputs` is a list of tuples containing which of the inputs to fix, and to which value.
#
# To get horixontal slices of the above GP, we'll fix second (index 1) input to -1, 0, and 1.5:

# %%
slices = [-1, 0, 1.5]
figure = GPy.plotting.plotting_library().figure(3, 
798516, 0.9860548555183497, 1.0296441358568469, 1.073233416195344, 1.1168226965338413, 1.1604119768723384, 1.2040012572108356, 1.2475905375493328, 1.29117981788783, 1.3347690982263272, 1.3783583785648243, 1.4219476589033215, 1.4655369392418196, 1.5091262195803168, 1.552715499918814, 1.5963047802573112, 1.6398940605958083, 1.6834833409343055, 1.7270726212728027, 1.7706619016112999, 1.814251181949797, 1.8578404622882942, 1.9014297426267923, 1.9450190229652895, 1.9886083033037867, 2.032197583642284, 2.075786863980781, 2.1193761443192782, 2.1629654246577754, 2.2065547049962726, 2.25014398533477, 2.293733265673267, 2.337322546011764, 2.380911826350262, 2.4245011066887594, 2.4680903870272566, 2.5116796673657538, 2.555268947704251, 2.598858228042748, 2.6424475083812453, 2.6860367887197425, 2.7296260690582397, 2.773215349396737, 2.816804629735234, 2.860393910073732, 2.9039831904122293, 2.9475724707507265, 2.9911617510892237, 3.034751031427721, 3.078340311766218, 3.121929592104715, 3.1655188724432124, 3.2091081527817096, 3.2526974331202068, 3.296286713458704, 3.339875993797202, 3.383465274135699, 3.4270545544741964, 3.4706438348126936, 3.5142331151511907, 3.557822395489688, 3.601411675828185, 3.645000956166683, 3.6885902365051795, 3.7321795168436775, 3.775768797182174, 3.819358077520672, 3.862947357859168,  ...

# %% [markdown]
# A few things to note:
#  * we've also passed the optional `ax` argument, to mnake the GP plot on a particular subplot
#  * the data look strange here: we're seeing slices of the GP, but all the data are displayed, even though they might not be close to the current slice.

# %% [markdown]
# To get vertical slices, we simply fixed the other input. We'll turn the display of data off also:

# %%
slices = [-1, 0, 1.5]
figure = GPy.plotting.plotting_library().figure(3, 1, 
                        shared_xaxes=True,
                        subplot_titles=('slice at -1', 
                                        'slice at 0', 
                                        'slice at 1.5', 
                                        )
                            )
for i, y in zip(range(3), slices):
    canvas = m.plot(figure=figure, fixed_inputs=[(0,y)], row=(i+1), plot_data=False)
GPy.plotting.show(canvas, filename='basic_gp_regression_notebook_slicing_vertical')
# Out:
# PosteriorExact _raw_predict
# PosteriorExact _raw_predict
# PosteriorExact _raw_predict
# PosteriorExact _raw_predict
# PosteriorExact _raw_predict
# PosteriorExact _raw_predict
# <div>
#
#
#             <div id="05e330fc-4247-46d6-967f-bf2232e5e12c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("05e330fc-4247-46d6-967f-bf2232e5e12c")) {
#                     Plotly.newPlot(
#                         '05e330fc-4247-46d6-967f-bf2232e5e12c',
#                         [{"line": {"color": "#3465a4", "width": 2}, "mode": "lines", "name": "Mean", "showlegend": true, "type": "scatter", "x": [-4.4630544384076964, -4.418092811405797, -4.373131184403899, -4.328169557402, -4.283207930400101, -4.238246303398202, -4.193284676396304, -4.1483230493944045, -4.1033614223925055, -4.058399795390606, -4.013438168388708, -3.968476541386809, -3.92351491438491, -3.8785532873830113, -3.8335916603811127, -3.7886300333792136, -3.7436684063773145, -3.698706779375416, -3.653745152373517, -3.608783525371618, -3.563821898369719, -3.5188602713678203, -3.4738986443659217, -3.4289370173640226, -3.383975390362124, -3.3390137633602253, -3.294052136358326, -3.249090509356427, -3.2041288823545284, -3.1591672553526298, -3.1142056283507307, -3.0692440013488316, -3.024282374346933, -2.9793207473450343, -2.934359120343135, -2.889397493341236, -2.8444358663393374, -2.7994742393374388, -2.7545126123355397, -2.7095509853336406, -2.664589358331742, -2.6196277313298433, -2.574666104327944, -2.5297044773260455